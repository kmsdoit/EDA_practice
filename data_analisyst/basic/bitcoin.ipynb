# %% [markdown]
# 데이터 수집: 크롤링

# %%
import san

bitcoin = san.get("ohlcv/bitcoin") # open,high,low,close,volume

# %%
bitcoin.head(1) # 가장 맨 위에 있는 값 뽑기
# Out:
#                            openPriceUsd  closePriceUsd  highPriceUsd  \
# datetime
# 2021-09-14 00:00:00+00:00  46732.444869   47092.493833  47213.518594
#
#                             lowPriceUsd        volume     marketcap
# datetime
# 2021-09-14 00:00:00+00:00  46210.873623  3.865215e+10  8.860953e+11

# %%
bitcoin.info() # Dataframe의 정보
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 366 entries, 2021-09-14 00:00:00+00:00 to 2022-09-14 00:00:00+00:00
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   openPriceUsd   366 non-null    float64
#  1   closePriceUsd  366 non-null    float64
#  2   highPriceUsd   366 non-null    float64
#  3   lowPriceUsd    366 non-null    float64
#  4   volume         366 non-null    float64
#  5   marketcap      366 non-null    float64
# dtypes: float64(6)
# memory usage: 20.0 KB

# %%
bitcoin.describe() # 값이 숫자라면, 여러 통계적인 값을 얻을 수 있다 => 수치형 데이터 요약
# Out:
#        openPriceUsd  closePriceUsd  highPriceUsd   lowPriceUsd        volume  \
# count    366.000000     366.000000    366.000000    366.000000  3.660000e+02
# mean   38925.213675   38856.280957  39768.751576  37928.232550  3.101502e+10
# std    13236.441651   13265.765947  13534.023938  12957.493017  9.487966e+09
# min    18826.846797   18837.667712  19358.505722  17718.876793  1.373656e+10
# 25%    24408.376438   24340.205068  25015.083256  23979.967581  2.506113e+10
# 50%    40258.576886   40124.668425  41008.136431  39306.368173  3.036328e+10
# 75%    47235.001916   47227.010725  48096.940308  46328.789246  3.554235e+10
# max    67464.502924   67566.830088  68744.031364  66382.061008  8.419661e+10
#
#           marketcap
# count  3.660000e+02
# mean   7.365069e+11
# std    2.484601e+11
# min    3.606167e+11
# 25%    4.654130e+11
# 50%    7.618296e+11
# 75%    8.926798e+11
# max    1.274831e+12

# %%
data = bitcoin.copy()
data['MA'] = data['closePriceUsd'].rolling(window=5,min_periods=1).mean()
data['trades'] = data['MA'] < data['closePriceUsd']
data['returns'] = data['closePriceUsd'].pct_change()
data['BACKTEST'] = (data['returns'].shift(-1) * data['trades'] + 1).cumprod()

# %%
data
# Out:
#                            openPriceUsd  closePriceUsd  highPriceUsd  \
# datetime
# 2021-09-14 00:00:00+00:00  46732.444869   47092.493833  47213.518594
# 2021-09-15 00:00:00+00:00  47097.998123   48176.346393  48450.468466
